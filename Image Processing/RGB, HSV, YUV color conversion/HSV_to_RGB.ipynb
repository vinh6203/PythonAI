# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
hsvFilename = 'hsv_cat.jpg'
filename = 'cat.jpg'
img = cv2.imread(hsvFilename) #BGR
img[:,:,[0,2]] = img[:,:,[2,0]] #BGR -> RGB
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (900, 1200, 3)

# %%
hsv_img = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2HSV)[:,:,[2,1,0]]
plt.imshow(hsv_img)
